# %%
from pandas import read_csv
from pandas import datetime 
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
# Out:
# <ipython-input-4-e4efc3d7109a>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
def parser(x):
    return datetime.strptime('202'+x, '%Y-%m')

series = read_csv('../datasets/caseIIIjx75T_production_record_first.csv', header=0, 
                  parse_dates=[0], 
                  index_col=0, 
                  squeeze=0, 
                  date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3322                 result = tools.to_datetime(
# -> 3323                     date_parser(*date_cols), errors="ignore", cache=cache_dates
#    3324                 )
#
# <ipython-input-5-04896f17c8ed> in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime('202'+x, '%Y-%m')
#       3
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3330                     return tools.to_datetime(
# -> 3331                         parsing.try_parse_dates(
#    3332                             parsing.concat_date_cols(date_cols),
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-5-04896f17c8ed> in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime('202'+x, '%Y-%m')
#       3
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime(data_string, format)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#
# ValueError: time data '20210-10' does not match format '%Y-%m'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-04896f17c8ed> in <module>
#       2     return datetime.strptime('202'+x, '%Y-%m')
#       3
# ----> 4 series = read_csv('../datasets/caseIIIjx75T_production_record_first.csv', header=0,
#       5                   parse_dates=[0],
#       6                   index_col=0,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2137
#    2138             names, data = self._do_date_conversions(names, data)
# -> 2139             index, names = self._make_index(data, alldata, names)
#    2140
#    2141         # maybe create a mi on the columns
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in _make_index(self, data, alldata, columns, indexnamerow)
#    1549         elif not self._has_complex_date_col:
#    1550             index = self._get_simple_index(alldata, columns)
# -> 1551             index = self._agg_index(index)
#    1552         elif self._has_complex_date_col:
#    1553             if not self._name_processed:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in _agg_index(self, index, try_parse_dates)
#    1628
#    1629             if try_parse_dates and self._should_parse_dates(i):
# -> 1630                 arr = self._date_conv(arr)
#    1631
#    1632             if self.na_filter:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3337                     )
#    3338                 except Exception:
# -> 3339                     return generic_parser(date_parser, *date_cols)
#    3340
#    3341     return converter
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\date_converters.py in generic_parser(parse_func, *cols)
#      98     for i in range(N):
#      99         args = [c[i] for c in cols]
# --> 100         results[i] = parse_func(*args)
#     101
#     102     return results
#
# <ipython-input-5-04896f17c8ed> in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime('202'+x, '%Y-%m')
#       3
#       4 series = read_csv('../datasets/caseIIIjx75T_production_record_first.csv', header=0,
#       5                   parse_dates=[0],
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '20210-10' does not match format '%Y-%m'
